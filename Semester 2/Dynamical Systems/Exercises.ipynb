# %%
t=var('t')
x=function('x')(t)
eqd=diff(x,2)+x==0
desolve(eqd,x,ics=[pi/2,1,-2])
# Out:
# 2*cos(t) + sin(t)

# %%
eqd=diff(x,2)+x==0
eq=desolve(eqd, x, ics=[pi/2, 1, -2])
plot(eq)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
equ=diff(x)+x==sin(t)
sol=desolve(equ, x)
sol
# Out:
# -1/2*((cos(t) - sin(t))*e^t - 2*_C)*e^(-t)

# %%
eq4=diff(x)==3*x+t^3
sol=desolve(eq4,x)
sol
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-67bdd4efb9df> in <module>
# ----> 1 eq4=diff(x)==Integer(3)*x+t**Integer(3)
#       2 sol=desolve(eq4,x)
#       3 sol
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__pow__ (build/cythonized/sage/rings/integer.c:15219)()
#    2206             return coercion_model.bin_op(left, right, operator.pow)
#    2207         # left is a non-Element: do the powering with a Python int
# -> 2208         return left ** int(right)
#    2209
#    2210     cpdef _pow_(self, other):
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NewSymbolicFunction' and 'int'

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==-x+3*y
deq2=diff(y,t)==3*x-y
syst=[deq1,deq2]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == 1/2*(x(0) + y(0))*e^(2*t) + 1/2*(x(0) - y(0))*e^(-4*t),
#  y(t) == 1/2*(x(0) + y(0))*e^(2*t) - 1/2*(x(0) - y(0))*e^(-4*t)]

# %%
sol=desolve_system(syst,[x,y],ics=[0, 1, 1])

# %%
sol
# Out:
# [x(t) == e^(2*t), y(t) == e^(2*t)]

# %%
f(t)=sol[0].rhs()
f(t)
# Out:
# e^(2*t)

# %%
g(t)=sol[1].rhs()
g(t)
# Out:
# e^(2*t)

# %%
parametric_plot((f(t),g(t)),(t,0,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
matrix([[5,6,6,8],[2,2,2,8],[6,6,2,8],[2,3,6,7]])
# Out:
# [5 6 6 8]
# [2 2 2 8]
# [6 6 2 8]
# [2 3 6 7]

# %%
P=matrix([[5,6,6,8],[2,2,2,8],[6,6,2,8],[2,3,6,7]])

# %%
J=diagonal_matrix([2,2,-1,0])

# %%
A=P*J*P^(-1)

# %%
A
# Out:
# [   58  57/2 -75/2   -56]
# [    8   7/2  -9/2    -8]
# [    8   3/2  -5/2    -8]
# [   58    30   -39   -56]

# %%
x,y = var('x y')
f=(x-2*x*y, (x^2/2)-y)
jacobian(f,(x,y))
# Out:
# [-2*y + 1     -2*x]
# [       x       -1]

# %%
jac = jacobian(f, (x,y))
A1 = jac.subs(x=0,y=0)
A2 = jac.subs(x=2,y=0)
A3 = jac.subs(x=1,y=1)
A1, A2, A3
# Out:
# (
# [ 1  0]  [ 1 -4]  [-1 -2]
# [ 0 -1], [ 2 -1], [ 1 -1]
# )

# %%
A1.eigenvalues()
# Out:
# [-1, 1]

# %%
A2.eigenvalues()
# Out:
# [-I*sqrt(7), I*sqrt(7)]

# %%
A3.eigenvalues()
# Out:
# [-I*sqrt(2) - 1, I*sqrt(2) - 1]

# %%
x,y = var('x y')
f=(x-2*x*y, (x^2/2)-y)
plot_vector_field((f[0], f[1]), (x,-2, 2.2),(y,-2, 1.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sol=desolve_odeint(f, ics, times, [x,y])
line(zip(sol[:,0],sol[:,1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a7647fece4fa> in <module>
# ----> 1 sol=desolve_odeint(f, ics, times, [x,y])
#       2 line(zip(sol[:,Integer(0)],sol[:,Integer(1)]))
#
# NameError: name 'ics' is not defined
